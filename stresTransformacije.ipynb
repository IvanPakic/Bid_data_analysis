# %% [markdown]
# ##Big Data Analysis
# Projekat za temu ima da istraži vezu između spavanja i stresa, kao i svakodnevni uticaj stresa na čoveka.
# Za tu potrebu koristiću dva data set-a, koja se mogu pronaći na sledećim linkovima:
#
# https://www.kaggle.com/datasets/laavanya/human-stress-detection-in-and-through-sleep
# https://www.kaggle.com/datasets/laavanya/stress-level-detection?select=Stress-Lysis.csv
#
#
# Dalji tok projekta ide po zadatoj specifikaciji, koja je propraćena dodatnim objašnjenjima.

# %%
# %fs ls FileStore/tables/stress.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/stress.csv/Stress_Lysis.csv</td><td>Stress_Lysis.csv</td><td>36495</td><td>1676071444000</td></tr></tbody></table></div>

# %%
# %fs ls FileStore/tables/sleep_stress.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/sleep_stress.csv/SaYoPillow.csv</td><td>SaYoPillow.csv</td><td>32492</td><td>1676071770000</td></tr></tbody></table></div>

# %% [markdown]
# U nastavku će biti prikazano učitavanje data set-a, kao i prikaz tabela i definisanje šema

# %%
#from pyspark.sql import Row, Column
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

df_stress = spark.read.csv("/FileStore/tables/stress.csv", header=True, inferSchema=True)
df_sleep_stress = spark.read.csv("/FileStore/tables/sleep_stress.csv", header=True, inferSchema=True)

# %%
display(df_stress)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Humidity</th><th>Temperature</th><th>Step_count</th><th>Stress_Level</th></tr></thead><tbody><tr><td>21.33</td><td>90.33</td><td>123</td><td>1</td></tr><tr><td>21.41</td><td>90.41</td><td>93</td><td>1</td></tr><tr><td>27.12</td><td>96.12</td><td>196</td><td>2</td></tr><tr><td>27.64</td><td>96.64</td><td>177</td><td>2</td></tr><tr><td>10.87</td><td>79.87</td><td>87</td><td>0</td></tr><tr><td>11.31</td><td>80.31</td><td>40</td><td>0</td></tr><tr><td>18.16</td><td>87.16</td><td>88</td><td>1</td></tr><tr><td>28.2</td><td>97.2</td><td>162</td><td>2</td></tr><tr><td>14.25</td><td>83.25</td><td>61</td><td>0</td></tr><tr><td>26.13</td><td>95.13</td><td>168</td><td>2</td></tr><tr><td>23.61</td><td>92.61</td><td>200</td><td>2</td></tr><tr><td>19.37</td><td>88.37</td><td>117</td><td>1</td></tr><tr><td>29.08</td><td>98.08</td><td>179</td><td>2</td></tr><tr><td>17.83</td><td>86.83</td><td>55</td><td>1</td></tr><tr><td>28.06</td><td>97.06</td><td>148</td><td>2</td></tr><tr><td>19.43</td><td>88.43</td><td>123</td><td>1</td></tr><tr><td>26.85</td><td>95.85</td><td>169</td><td>2</td></tr><tr><td>26.51</td><td>95.51</td><td>135</td><td>2</td></tr><tr><td>29.49</td><td>98.49</td><td>149</td><td>2</td></tr><tr><td>20.94</td><td>89.94</td><td>122</td><td>1</td></tr><tr><td>28.6</td><td>97.6</td><td>131</td><td>2</td></tr><tr><td>18.62</td><td>87.62</td><td>43</td><td>1</td></tr><tr><td>14.43</td><td>83.43</td><td>79</td><td>0</td></tr><tr><td>26.69</td><td>95.69</td><td>153</td><td>2</td></tr><tr><td>15.67</td><td>84.67</td><td>21</td><td>1</td></tr><tr><td>26.63</td><td>95.63</td><td>147</td><td>2</td></tr><tr><td>17.58</td><td>86.58</td><td>30</td><td>1</td></tr><tr><td>21.53</td><td>90.53</td><td
</td><td>24.656</td><td>91.328</td><td>15.32</td><td>89.328</td><td>98.32</td><td>1.328</td><td>71.64</td><td>3</td></tr><tr><td>53.68</td><td>18.736</td><td>94.736</td><td>8.736</td><td>93.104</td><td>81.84</td><td>5.736</td><td>56.84</td><td>1</td></tr><tr><td>78.56</td><td>21.856</td><td>93.856</td><td>11.856</td><td>91.856</td><td>94.28</td><td>4.784</td><td>64.64</td><td>2</td></tr><tr><td>50.96</td><td>18.192</td><td>94.192</td><td>8.192</td><td>92.288</td><td>80.48</td><td>5.192</td><td>55.48</td><td>1</td></tr><tr><td>94.76</td><td>25.936</td><td>91.968</td><td>16.92</td><td>89.968</td ...

# %% [markdown]
# ####Objašnjenje skraćenica:
#
# sr0 - snoring range of the user
# rr - respiration rate
# t - body temperature
# lm - limb movement rate
# bo - blood oxygen levels
# rem - eye movement
# sr6 - number of hours of sleep
# hr - heart rate
# sl - Stress Levels

# %%
stress_schema = StructType(
    [StructField('humidity', DoubleType(), True),
     StructField('temperature', DoubleType(), True),
     StructField('step_count', IntegerType(), True),
     StructField('stress_level', IntegerType(), True)])

sleep_stress_schema = StructType(
    [StructField('sr0', DoubleType(), True),
     StructField('rr', DoubleType(), True),
     StructField('t', DoubleType(), True),
     StructField('lm', DoubleType(), True),
     StructField('bo', DoubleType(), True),
     StructField('rem', DoubleType(), True),
     StructField('sr6', DoubleType(), True),
     StructField('hr', DoubleType(), True),
     StructField('sl', IntegerType(), True)])

# %%
stress_df = spark.read.csv("/FileStore/tables/stress.csv", header=True, schema=stress_schema)
sleep_stress_df = spark.read.csv("/FileStore/tables/sleep_stress.csv", header=True, schema=sleep_stress_schema)

# %% [markdown]
# Ispis šema

# %%
stress_df.printSchema()
# Out:
# root
#  |-- humidity: double (nullable = true)
#  |-- temperature: double (nullable = true)
#  |-- step_count: integer (nullable = true)
#  |-- stress_level: integer (nullable = true)

# %%
sleep_stress_df.printSchema()
# Out:
# root
#  |-- sr0: double (nullable = true)
#  |-- rr: double (nullable = true)
#  |-- t: double (nullable = true)
#  |-- lm: double (nullable = true)
#  |-- bo: double (nullable = true)
#  |-- rem: double (nullable = true)
#  |-- sr6: double (nullable = true)
#  |-- hr: double (nullable = true)
#  |-- sl: integer (nullable = true)

# %% [markdown]
# Potrebno je odraditi keširanje podataka kako bismo dobili što bolje performanse

# %%
stress_df.cache()
sleep_stress_df.cache()
# Out:
# Out[8]: DataFrame[sr0: double, rr: double, t: double, lm: double, bo: double, rem: double, sr6: double, hr: double, sl: int]

# %% [markdown]
# ####Transformacija prvog data set-a (stress)

# %%
stress_df.show()
# Out:
# +--------+-----------+----------+------------+
# |humidity|temperature|step_count|stress_level|
# +--------+-----------+----------+------------+
# |   21.33|      90.33|       123|           1|
# |   21.41|      90.41|        93|           1|
# |   27.12|      96.12|       196|           2|
# |   27.64|      96.64|       177|           2|
# |   10.87|      79.87|        87|           0|
# |   11.31|      80.31|        40|           0|
# |   18.16|      87.16|        88|           1|
# |    28.2|       97.2|       162|           2|
# |   14.25|      83.25|        61|           0|
# |   26.13|      95.13|       168|           2|
# |   23.61|      92.61|       200|           2|
# |   19.37|      88.37|       117|           1|
# |   29.08|      98.08|       179|           2|
# |   17.83|      86.83|        55|           1|
# |   28.06|      97.06|       148|           2|
# |   19.43|      88.43|       123|           1|
# |   26.85|      95.85|       169|           2|
# |   26.51|      95.51|       135|           2|
# |   29.49|      98.49|       149|           2|
# |   20.94|      89.94|       122|           1|
# +--------+-----------+----------+------------+
# only showing top 20 rows

# %% [markdown]
# Promena naziva kolona

# %%
stress_df = stress_df.withColumnRenamed("humidity", "vlažnost")
stress_df = stress_df.withColumnRenamed("temperature", "temperatura")
stress_df = stress_df.withColumnRenamed("step_count", "broj_koraka")
stress_df = stress_df.withColumnRenamed("stress_level", "nivo_stresa")

# %% [markdown]
# Brisanje duplikata

# %%
stress_df = stress_df.dropDuplicates()

# %% [markdown]
# Filtriranje u odnosu na broj pređenih koraka

# %%
stress_df = stress_df.filter(stress_df['broj_koraka'] > 50)
#display(stress_df)

# %% [markdown]
# Filtriranje u odnosu na temperaturu

# %%
stress_df = stress_df.filter(stress_df['temperatura'] > 80)

# %%
stress_df.select('temperatura').distinct().show(truncate=False)
# Out:
# +-----------+
# |temperatura|
# +-----------+
# |87.16      |
# |95.69      |
# |98.49      |
# |98.08      |
# |89.94      |
# |96.12      |
# |88.43      |
# |95.85      |
# |90.41      |
# |96.64      |
# |90.33      |
# |83.25      |
# |86.83      |
# |83.43      |
# |95.51      |
# |92.61      |
# |88.37      |
# |97.2       |
# |97.6       |
# |95.13      |
# +-----------+
# only showing top 20 rows

# %% [markdown]
# Pronalazak svih nivoa stresa u data set-u

# %%
stress_df.select('nivo_stresa').distinct().show()
# Out:
# +-----------+
# |nivo_stresa|
# +-----------+
# |          1|
# |          2|
# |          0|
# +-----------+

# %% [markdown]
# Odbaciti osobe bez stresa tj. sa stress level-om 0

# %%
stress_df = stress_df.filter(stress_df['nivo_stresa'] > 0)
stress_df.select('nivo_stresa').distinct().show()
# Out:
# +-----------+
# |nivo_stresa|
# +-----------+
# |          1|
# |          2|
# +-----------+

# %% [markdown]
# Konačan ispis (stress) data set-a

# %%
display(stress_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vlažnost</th><th>temperatura</th><th>broj_koraka</th><th>nivo_stresa</th></tr></thead><tbody><tr><td>15.97</td><td>84.97</td><td>51</td><td>1</td></tr><tr><td>24.64</td><td>93.64</td><td>161</td><td>2</td></tr><tr><td>26.57</td><td>95.57</td><td>141</td><td>2</td></tr><tr><td>25.71</td><td>94.71</td><td>197</td><td>2</td></tr><tr><td>21.57</td><td>90.57</td><td>109</td><td>1</td></tr><tr><td>26.54</td><td>95.54</td><td>138</td><td>2</td></tr><tr><td>26.06</td><td>95.06</td><td>161</td><td>2</td></tr><tr><td>27.93</td><td>96.93</td><td>135</td><td>2</td></tr><tr><td>19.75</td><td>88.75</td><td>117</td><td>1</td></tr><tr><td>17.92</td><td>86.92</td><td>64</td><td>1</td></tr><tr><td>28.84</td><td>97.84</td><td>155</td><td>2</td></tr><tr><td>26.61</td><td>95.61</td><td>145</td><td>2</td></tr><tr><td>21.51</td><td>90.51</td><td>103</td><td>1</td></tr><tr><td>27.82</td><td>96.82</td><td>195</td><td>2</td></tr><tr><td>26.34</td><td>95.34</td><td>189</td
# %% [markdown]
# ####Transformacija drugog data set-a (sleep_stress)

# %%
sleep_stress_df.show()
# Out:
# +------+------+------+------+------+------+-----+-----+---+
# |   sr0|    rr|     t|    lm|    bo|   rem|  sr6|   hr| sl|
# +------+------+------+------+------+------+-----+-----+---+
# |  93.8| 25.68| 91.84|  16.6| 89.84|  99.6| 1.84| 74.2|  3|
# | 91.64|25.104|91.552| 15.88|89.552| 98.88|1.552|72.76|  3|
# |  60.0|  20.0|  96.0|  10.0|  95.0|  85.0|  7.0| 60.0|  1|
# | 85.76|23.536|90.768| 13.92|88.768| 96.92|0.768|68.84|  3|
# | 48.12|17.248|97.872| 6.496|96.248| 72.48|8.248|53.12|  0|
# | 56.88|19.376|95.376| 9.376|94.064| 83.44|6.376|58.44|  1|
# |  47.0|  16.8|  97.2|   5.6|  95.8|  68.0|  7.8| 52.0|  0|
# |  50.0|  18.0|  99.0|   8.0|  97.0|  80.0|  9.0| 55.0|  0|
# | 45.28|16.112|96.168| 4.224|95.112| 61.12|7.112|50.28|  0|
# | 55.52|19.104|95.104| 9.104|93.656| 82.76|6.104|57.76|  1|
# | 73.44|21.344|93.344|11.344|91.344| 91.72|4.016|63.36|  2|
# | 59.28|19.856|95.856| 9.856|94.784| 84.64|6.856|59.64|  1|
# |  48.6| 17.44| 98.16|  6.88| 96.44|  74.4| 8.44| 53.6|  0|
# |96.288|26.288| 85.36|17.144|82.432|100.36|  0.0|75.72|  4|
# |  87.8| 24.08| 91.04|  14.6| 89.04|  97.6| 1.04| 70.2|  3|
# | 52.32|18.464|94.464| 8.464|92.696| 81.16|5.464|56.16|  1|
# | 52.64|18.528|94.528| 8.528|92.792| 81.32|5.528|56.32|  1|
# | 86.24|23.664|90.832| 14.08|88.832| 97.08|0.832|69.16|  3|
# | 81.56|22.416|90.208| 12.52|88.208| 95.52|0.208|66.04|  3|
# | 63.68|20.368|92.368|10.368|90.368| 86.84|2.552|60.92|  2|
# +------+------+------+------+------+------+-----+-----+---+
# only showing top 20 rows

# %% [markdown]
# Obrisaću kolone lm i rem, jer smatram da nisu potrebne za dalju analizu

# %%
sleep_stress_df = sleep_stress_df.drop('lm')
sleep_stress_df = sleep_stress_df.drop('rem')

# %% [markdown]
# Promena nazaiva kolona

# %%
sleep_stress_df = sleep_stress_df.withColumnRenamed("sr0", "hrkanje")
sleep_stress_df = sleep_stress_df.withColumnRenamed("rr", "brzina_disanja")
sleep_stress_df = sleep_stress_df.withColumnRenamed("t", "temperatura_tela")
sleep_stress_df = sleep_stress_df.withColumnRenamed("bo", "kiseonik_u_krvi")
sleep_stress_df = sleep_stress_df.withColumnRenamed("sr6", "dužina_sna")
sleep_stress_df = sleep_stress_df.withColumnRenamed("hr", "puls")
sleep_stress_df = sleep_stress_df.withColumnRenamed("sl", "stres")

# %% [markdown]
# Ukloniću granične vrednosti kod kolone brzina disanja. Pod tim smatram da brzina manja od 15 i veća od 25 znači da osoba nije zdrav uzorak u tom trenutku.

# %%
sleep_stress_df = sleep_stress_df.filter(sleep_stress_df['brzina_disanja'] > 15)
sleep_stress_df = sleep_stress_df.filter(sleep_stress_df['brzina_disanja'] < 25)
display(sleep_stress_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
>21.856</td><td>93.856</td><td>91.856</td><td>4.784</td><td>64.64</td><td>2</td></tr><tr><td>50.96</td><td>18.192</td><td>94.192</td><td>92.288</td><td>5.192</td><td>55.48</td><td>1</td></tr><tr><td>62.08</td><td>20.208</td><td>92.208</td><td>90.208</td><td>2.312</td><td>60.52</td><td>2</td></tr><tr><td>49.12</td><td>17.648</td><td>98.472</td><td>96.648</td><td>8.648</td><td>54.12</td><td>0</td></tr><tr><td>47.68</td><td>17.072</td><td>97.608</td><td>96.072</td><td>8.072</td><td>52.68</td><td>0</td></tr><tr><td>60.0</td><td>20.0</td><td>92.0</td><td>90.0</td><td>2.0</td><td>60.0</td><td>2</td></tr><tr><td>86.72</td><td>23.792</td><td>90.896</td><td>88.896</td><td>0.896</td><td>69.48</td><td>3</td></tr><tr><td>48.48</td><td>17.392</td><td>98.088</td><td>96.392</td><td>8.392</td><td>53.48</td><td>0</td></tr><tr><td>46.12</td><td>16.448</td><td>96.672</td><td>95.448</td><td>7.448</td><td>51.12</td><td>0</td></tr><tr><td>60.96</td><td>20.096</td><td>92.096</td><td>90.096</td><td>2.144</td><td>60.24</td><td>2</td></tr><tr><td>65.6</td><td>20.56</td><td>92.56</td><td>90.56</td><td>2.84</td><td>61.4</td><td>2</td></tr><tr><td>75.36</td><td>21.536</td><td>93.536</td><td>91.536</td><td>4.304</td><td>63.84</td><td>2</td></tr><tr><td>49.28</td><td>17.712</td><td>98.568</td><td>96.712</td><td>8.712</td><td>54.2 ...

# %%
#sleep_stress_df.withColumnRenamed("kiseonik_u_krvi", "max kiseonika").select("max kiseonika").where(col("max kiseonika") > 5).show(5, False)
#sleep_stress_df.withColumnRenamed("puls", "max puls").select("max puls").where(col("max puls") > 5).show(5, False)

# %% [markdown]
# U nastavku ću prikazati nivo stresa koji se u ovom data set-u pojavljuje

# %%
sleep_stress_df.select('stres').distinct().show()
# Out:
# +-----+
# |stres|
# +-----+
# |    1|
# |    3|
# |    2|
# |    0|
# +-----+

# %% [markdown]
# Ovim korakom ću ukloniti slučajeve bez ili sa vrlo niskim nivoom stresa

# %%
sleep_stress_df = sleep_stress_df.filter(sleep_stress_df['stres'] > 0)
sleep_stress_df.select('stres').distinct().show()
# Out:
# +-----+
# |stres|
# +-----+
# |    1|
# |    3|
# |    2|
# +-----+

# %%
#sleep_stress_df = sleep_stress_df.groupBy("dužina_sna").agg("dužins_sna":"avg")
sleep_stress_df.select(mean ('dužina_sna')).show()
# Out:
# +-----------------+
# |  avg(dužina_sna)|
# +-----------------+
# |3.661664739884393|
# +-----------------+

# %% [markdown]
# Odbaciću hrkanje koje je manje od 50 Db

# %%
sleep_stress_df = sleep_stress_df.filter(sleep_stress_df['hrkanje'] > 50)
#sleep_stress_df.select('hrkanje').distinct().show()

# %% [markdown]
# U sledećem koraku ću samo pogledati da li je hrkanje veće od 100Db
# To ću pokazati preko groupBy, gde bih izdvojio prvih 15 najvećih uzoraka

# %%
sleep_stress_df .select(col('hrkanje').alias('max hrkanja')).orderBy(col('hrkanje').desc()).limit(15).show()
# Out:
# +-----------+
# |max hrkanja|
# +-----------+
# |      91.16|
# |      91.04|
# |      90.92|
# |       90.8|
# |      90.68|
# |      90.56|
# |      90.44|
# |      90.32|
# |       90.2|
# |      90.08|
# |      89.96|
# |      89.84|
# |      89.72|
# |       89.6|
# |      89.48|
# +-----------+

# %%
display(sleep_stress_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/stresTransformacije/df.csv/_committed_2056761049369130746</td><td>_committed_2056761049369130746</td><td>201</td><td>1676207400000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_committed_2417139068891011757</td><td>_committed_2417139068891011757</td><td>202</td><td>1676250187000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_committed_2636612712425275446</td><td>_committed_2636612712425275446</td><td>199</td><td>1676203372000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_committed_2783157834056723206</td><td>_committed_2783157834056723206</td><td>201</td><td>1676207092000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_committed_366300356189847713</td><td>_committed_366300356189847713</td><td>200</td><td>1676288340000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_committed_4600391673446376028</td><td>_committed_4600391673446376028</td><td>200</td><td>1676203273000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_committed_5912154206775318348</td><td>_committed_5912154206775318348</td><td>201</td><td>1676207112000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_committed_6338825090602400376</td><td>_committed_6338825090602400376</td><td>200</td><td>1676207063000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_committed_7052203698561823375</td><td>_committed_7052203698561823375</td><td>201</td><td>1676207618000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_committed_7501370630618151542</td><td>_committed_7501370630618151542</td><td>212</td><td>1676160712000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_committed_7674697229553339556</td><td>_committed_7674697229553339556</td><td>201</td><td>1676207736000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_committed_8982373504796055868</td><td>_committed_8982373504796055868</td><td>198</td><td>1676289563000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_started_366300356189847713</td><td>_started_366300356189847713</td><td>0</td><td>1676288336000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/_started_8982373504796055868</td><td>_started_8982373504796055868</td><td>0</td><td>1676289559000</td></tr><tr><td>dbfs:/stresTransformacije/df.csv/part-00000-tid-8982373504796055868-90c921e0-8718-4c09-8d7f-633e9db72066-30-1-c000.csv</td><td>part-00000-tid-8982373504796055868-90c921e0-8718-4c09-8d7f-633e9db72066-30-1-c000.csv</td><td>22843777</td><td>1676289562000</td></tr></tbody></table></div>

# %%
all_df.printSchema()
# Out:
# root
#  |-- hrkanje: double (nullable = true)
#  |-- brzina_disanja: double (nullable = true)
#  |-- temperatura_tela: double (nullable = true)
#  |-- kiseonik_u_krvi: double (nullable = true)
#  |-- dužina_sna: double (nullable = true)
#  |-- puls: double (nullable = true)
#  |-- stres: integer (nullable = true)
#  |-- vlažnost: double (nullable = true)
#  |-- broj_koraka: integer (nullable = true)
#  |-- nivo_stresa: integer (nullable = true)

# %%
df_str  = 'dbfs:/streaming/df.csv'
all_df.write.csv(df_str, header=True, mode='overwrite')

#dbutils.fs.rm("dbfs:/streaming", recurse=True)
